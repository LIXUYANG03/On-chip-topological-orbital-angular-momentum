# %%
import matplotlib as mpl

from mpl_toolkits.mplot3d import Axes3D

import numpy as np

import matplotlib.pyplot as plt

# %%
ytplist=[]
xlist = []
for i in range(1, 41):
    xlist.append(i)
ylist = [1.440579,1.440576,1.440248,1.440247,1.440240,1.440240,1.440238,1.440236,1.440233,1.440232,1.440222,1.440221,1.440218,1.440217,1.440202,1.440201,1.440198,1.440197,1.440182,1.440182,1.440181,1.440179,1.440147,1.440124,1.440118,1.440114,1.440036,1.440033,1.440032,1.440031,1.440006,1.439999,1.439999,1.439990,1.439964,1.439955,1.439953,1.439943,1.439917,1.439915]
xtplist=[23, 24, 25, 26]
for i in xtplist:
    ytplist.append(ylist[i-1])
plt.plot(xlist, ylist,'.')
plt.plot(xtplist, ytplist, 'r.')

# %%
1.440586,1.440583,1.440247,1.440246,1.440239,1.440238,1.440237,1.440232,1.440232,1.440229,1.440223,1.440221,1.440211,1.440209,1.440203,1.440202,1.440188,1.440188,1.440181,1.440181,1.440147,1.440114,1.440095,1.440085,1.440039,1.440035,1.440026,1.440023,1.440004,1.439995,1.439993,1.439986,1.439957,1.439947,1.439943,1.439936,1.439918,1.439914,1.439914,1.439911,1.439900,1.439899,1.439892,1.439887,1.439885,1.439881,1.439877,1.439873,1.439845,1.439839,1.439829,1.439823,1.439817,1.439807,1.439807,1.439807,1.439803,1.439799,1.439794,1.439783,

# %% [markdown]
# ## 2

# %%
ytplist=[]
xlist = []
ylist = []
yzlist = [1.440586,1.440583,1.440247,1.440246,1.440239,1.440238,1.440237,1.440232,1.440232,1.440229,1.440223,1.440221,1.440211,1.440209,1.440203,1.440202,1.440188,1.440188,1.440181,1.440181,1.440147,1.440114,1.440095,1.440085,1.440039,1.440035,1.440026,1.440023,1.440004,1.439995,1.439993,1.439986,1.439957,1.439947,1.439943,1.439936,1.439918,1.439914,1.439914,1.439911,1.439900,1.439899,1.439892,1.439887,1.439885,1.439881,1.439877,1.439873,1.439845,1.439839,1.439829,1.439823,1.439817,1.439807,1.439807,1.439807,1.439803,1.439799,1.439794,1.439783,]
yslist = [1.440578,1.440576,1.440147,1.440136,1.440128,1.440114,1.439995,1.439995,1.439980,1.439978,1.439955,1.439951,1.439920,1.439915,1.439915,1.439915,1.439912,1.439911,1.439905,1.439904,1.439898,1.439896,1.439885,1.439883,1.439877,1.439875,1.439871,1.439868,1.439854,1.439850,1.439842,1.439836,1.439825,1.439813,1.439812,1.439807,1.439801,1.439792,1.439775,1.439763,1.439754,1.439750,1.439747,1.439740,1.439730,1.439703,1.439691,1.439690,1.439682,1.439678,1.439669,1.439665,1.439665,1.439661,1.439661,1.439657,1.439655,1.439646,1.439644,1.439641,]

for i in range(60):
    xlist.append(i)
    ylist.append(yzlist[i]-yslist[3])
# xtplist=[23, 24, 25, 26]
# for i in xtplist:
#     ytplist.append(ylist[i-1])

plt.plot(xlist, yzlist,'.')
plt.plot(xlist, yslist,'.')
# plt.plot(xtplist, ytplist, 'r.')

# %%
plt.plot(xlist, ylist, '.')
xtplist=[20, 21, 22, 23]
for i in xtplist:
    ytplist.append(ylist[i-1])
plt.plot(xtplist, ytplist, 'r.')

# %% [markdown]
# ## 8 16

# %%
ytplist=[]
xlist = []
ylist = []
yzlist = [1.440247,1.440246,1.440239,1.440238,1.440237,1.440232,1.440232,1.440229,1.440223,1.440221,1.440211,1.440209,1.440203,1.440202,1.440188,1.440188,1.440181,1.440181,1.440147,1.440114,1.440095,1.440085,1.440039,1.440035,1.440026,1.440023,1.440004,1.439995,1.439993,1.439986,1.439957,1.439947,1.439943,1.439936,1.439918,1.439914,1.439914,1.439911,]

for i in range(38):
    xlist.append(i)
xtplist=[18, 19, 20, 21]
y0 = (yzlist[18] + yzlist[19] + yzlist[20] + yzlist[21])/4
for i in xtplist:
    ytplist.append(yzlist[i])

for i in range(38):
    yzlist[i] -= y0
for i in range(4): 
    ytplist[i] -= y0
    

plt.plot(xlist, yzlist,'.', color = 'gray')
plt.plot(xtplist, ytplist, 'r.')

plt.ylim(-2.2e-4, 2.2e-4)
plt.xticks([0, 10, 20, 30, 40],font={'family':'Arial', 'size':25}) 
plt.rcParams['font.family']='Times New Roman ,SimSun '# 设置字体族，中文为SimSun，英文为Times New Roman
plt.rcParams['mathtext.fontset'] = 'stix'
plt.xlabel('Index of eigenstates', fontsize = 30)
plt.ylabel(r'($\beta-\beta_0)/g_1$', fontsize = 35)

# g1 = 1e-4
# Out:
# Text(0, 0.5, '($\\beta-\\beta_0)/g_1$')

# %% [markdown]
# ## 2 near

# %%
ytplist=[]
xlist = []
ylist = []
yzlist = [1.440610,1.440608,1.440342,1.440342,1.440337,1.440336,1.440315,1.440310,1.440306,1.440301,1.440295,1.440291,1.440250,1.440245,1.440244,1.440240,1.440181,1.440178,1.440176,1.440173,1.440148,1.440114,1.440028,1.440020,1.439961,1.439946,1.439946,1.439935,1.439913,1.439912,1.439912,1.439894,1.439893,1.439886,1.439873,1.439871,1.439860,1.439844,1.439843,1.439838]

for i in range(40):
    xlist.append(i)
xtplist=[20, 21, 22, 23]
for i in xtplist:
    ytplist.append(yzlist[i])

plt.plot(xlist, yzlist,'.')
plt.plot(xtplist, ytplist, 'r.')

# %% [markdown]
# ## 2 far

# %%
ytplist=[]
xlist = []
ylist = []
yzlist = [1.440182,1.440182,1.440181,1.440178,1.440177,1.440174,1.440172,1.440172,1.440172,1.440170,1.440168,1.440167,1.440166,1.440165,1.440163,1.440162,1.440159,1.440158,1.440147,1.440132,1.440120,1.440114,1.440099,1.440097,1.440091,1.440090,1.440087,1.440085,1.440082,1.440081,1.440079,1.440075,1.440073,1.440073,1.440071,1.440065,1.440065,1.440064]

for i in range(38):
    xlist.append(i)
xtplist=[18, 19, 20, 21]
y0 = (yzlist[18] + yzlist[19] + yzlist[20] + yzlist[21])/4
for i in xtplist:
    ytplist.append(yzlist[i])

for i in range(38):
    yzlist[i] -= y0
for i in range(4): 
    ytplist[i] -= y0
    

plt.plot(xlist, yzlist,'.', markersize = 10, color = 'black')
plt.plot(xtplist, ytplist, 'r.', markersize = 10)

plt.ylim(-7e-5, 7e-5)
plt.xticks([0, 10, 20, 30, 40],font={'family':'Arial', 'size':30})
plt.yticks([-5e-5, 0, 5e-5], ['-5', '0', '5'],font={'family':'Arial', 'size':30})
plt.rcParams['font.family']='Times New Roman ,SimSun '# 设置字体族，中文为SimSun，英文为Times New Roman
plt.rcParams['mathtext.fontset'] = 'stix'
plt.xlabel('Mode number', fontsize = 32)
plt.ylabel(r'($\beta-\beta_0)$', fontsize = 32)

# g = 1e-5
# Out:
# Text(0, 0.5, '($\\beta-\\beta_0)$')

# %% [markdown]
# ## 12 24

# %%
ytplist=[]
xlist = []
ylist = []
yzlist = [1.440205,1.440204,1.440202,1.440198,1.440197,1.440195,1.440192,1.440192,1.440189,1.440188,1.440186,1.440186,1.440179,1.440179,1.440178,1.440177,1.440170,1.440169,1.440147,1.440121,1.440114,1.440110,1.440078,1.440077,1.440063,1.440063,1.440062,1.440060,1.440049,1.440047,1.440041,1.440038,1.440030,1.440027,1.440022,1.440017,1.440013,1.440012]

for i in range(38):
    xlist.append(i)
xtplist=[18, 19, 20, 21]
for i in xtplist:
    ytplist.append(yzlist[i])

plt.plot(xlist, yzlist,'.')
plt.plot(xtplist, ytplist, 'r.')

# %% [markdown]
# ## 4

# %%
ytplist=[]
xlist = []
ylist = []
yzlist = [1.440182,1.440182,1.440180,1.440180,1.440176,1.440176,1.440172,1.440172,1.440169,1.440169,1.440169,1.440169,1.440167,1.440167,1.440165,1.440164,1.440161,1.440161,1.440158,1.440158,1.440147,1.440135,1.440128,1.440114,1.440099,1.440099,1.440092,1.440091,1.440086,1.440086,1.440084,1.440083,1.440082,1.440082,1.440076,1.440076,1.440075,1.440075]

for i in range(38):
    xlist.append(i)

xtplist=[20, 21, 22, 23]
y0 = (yzlist[20] + yzlist[21] + yzlist[22] + yzlist[23])/4

for i in xtplist:
    ytplist.append(yzlist[i])

for i in range(38):
    yzlist[i] -= y0
for i in range(4): 
    ytplist[i] -= y0
    
plt.plot(xlist, yzlist,'.', markersize = 10, color = 'black')
plt.plot(xtplist, ytplist, 'r.', markersize = 10)

plt.ylim(-6e-5, 6e-5)
plt.xticks([0, 10, 20, 30, 40],font={'family':'Arial', 'size':30})
plt.yticks([-5e-5, 0, 5e-5], ['-5', '0', '5'],font={'family':'Arial', 'size':30})
plt.rcParams['font.family']='Times New Roman ,SimSun '# 设置字体族，中文为SimSun，英文为Times New Roman
plt.rcParams['mathtext.fontset'] = 'stix'
plt.xlabel('Mode number', fontsize = 32)
plt.ylabel(r'($\beta-\beta_0)$', fontsize = 32)

# g = 1e-5
# Out:
# Text(0, 0.5, '($\\beta-\\beta_0)$')

# %% [markdown]
# ## Logic

# %%
ytplist=[]
xlist = []
ylist = []
yzlist = [1.440254,1.440252,1.440251,1.440247,1.440245,1.440242,1.440232,1.440226,1.440224,1.440213,1.440211,1.440203,1.440191,1.440184,1.440172,1.440168,1.440143,1.440142,1.440122,1.440120,1.440119,1.440119,1.440082,1.440078,1.440035,1.440031,1.440012,1.440000,1.439979,1.439959,1.439956,1.439931,1.439925,1.439922,1.439918,1.439907]
for i in range(len(yzlist)):
    xlist.append(i)

xtplist=[18, 19, 20, 21]
y0 = (yzlist[19] + yzlist[20])/2

for i in xtplist:
    ytplist.append(yzlist[i])

for i in range(len(yzlist)):
    yzlist[i] -= y0
for i in range(len(xtplist)): 
    ytplist[i] -= y0
    
plt.plot(xlist, yzlist,'.', markersize = 10, color = 'black')
plt.plot(xtplist, ytplist, 'r.', markersize = 10)

plt.ylim(-2.5e-4, 2.1e-4)
plt.xticks([0, 10, 20, 30, 40],font={'family':'Arial', 'size':30})
plt.yticks([-2e-4, 0, 2e-4], ['-2', '0', '2'],font={'family':'Arial', 'size':30})
plt.rcParams['font.family']='Times New Roman, SimSun '# 设置字体族，中文为SimSun，英文为Times New Roman
plt.rcParams['mathtext.fontset'] = 'stix'
plt.xlabel('Mode number', fontsize = 32)
plt.ylabel(r'($\beta-\beta_0)$', fontsize = 32)

# g = 1e-5
# Out:
# Text(0, 0.5, '($\\beta-\\beta_0)$')

# %%
ytplist=[]
xlist = []
ylist = []
yzlist = [1.440254,1.440252,1.440251,1.440247,1.440245,1.440242,1.440232,1.440226,1.440224,1.440213,1.440211,1.440203,1.440191,1.440184,1.440172,1.440168,1.440143,1.440142,1.440122,1.440120,1.440119,1.440119,1.440082,1.440078,1.440035,1.440031,1.440012,1.440000,1.439979,1.439959,1.439956,1.439931,1.439925,1.439922,1.439918,1.439907]
for i in range(len(yzlist)):
    xlist.append(i)

xtplist=[18, 19, 20, 21]
y0 = (yzlist[19] + yzlist[20])/2

for i in xtplist:
    ytplist.append(yzlist[i])

for i in range(len(yzlist)):
    yzlist[i] -= y0
for i in range(len(xtplist)): 
    ytplist[i] -= y0
    
plt.plot(xlist, yzlist,'.', markersize = 10, color = 'black')
plt.plot(xtplist, ytplist, 'r.', markersize = 10)

plt.ylim(-2.5e-4, 2.1e-4)
plt.xticks([0, 10, 20, 30, 40],font={'family':'Arial', 'size':30})
plt.yticks([-2e-4, 0, 2e-4], ['-2', '0', '2'],font={'family':'Arial', 'size':30})
plt.rcParams['font.family']='Times New Roman, SimSun '# 设置字体族，中文为SimSun，英文为Times New Roman
plt.rcParams['mathtext.fontset'] = 'stix'
plt.xlabel('Mode number', fontsize = 32)
plt.ylabel(r'($\beta-\beta_0)$', fontsize = 32)

# g = 1e-5
# Out:
# Text(0, 0.5, '($\\beta-\\beta_0)$')

# %% [markdown]
# ## Logic more

# %%
ytplist=[]
xlist = []
ylist = []
yzlist = [1.440585,1.440583,1.440579,1.440577,1.440255,1.440254,1.440250,1.440249,1.440248,1.440245,1.440245,1.440243,1.440240,1.440239,1.440232,1.440231,1.440227,1.440226,1.440218,1.440216,1.440212,1.440208,1.440205,1.440198,1.440191,1.440187,1.440184,1.440180,1.440170,1.440168,1.440160,1.440143,1.440142,1.440140,1.440123,1.440120,1.440119,1.440119,1.440083,1.440080,1.440073,1.440050,1.440042,1.440038,1.440020,1.440012,1.440012,1.440000,1.439990,1.439974,1.439971,1.439955,1.439955,1.439943,1.439933,1.439932,1.439926,1.439922,1.439921,1.439917,1.439915,1.439907,1.439906,1.439905,1.439901,1.439893,1.439883,1.439879,1.439878,1.439876,1.439868,1.439866,1.439860,1.439859,1.439856,1.439851,1.439848,1.439848,1.439845,1.439843]
for i in range(len(yzlist)):
    xlist.append(i)

xtplist=[34, 35, 36, 37]
y0 = (yzlist[35] + yzlist[36])/2

for i in xtplist:
    ytplist.append(yzlist[i])

for i in range(len(yzlist)):
    yzlist[i] -= y0
for i in range(len(xtplist)): 
    ytplist[i] -= y0
    
plt.plot(xlist, yzlist,'.', markersize = 10, color = 'black')
plt.plot(xtplist, ytplist, 'r.', markersize = 10)
plt.xlim(0, 65)
plt.ylim(-2e-4, 1.8e-4)
plt.xticks([0, 10, 20, 30, 40, 50, 60],font={'family':'Arial', 'size':30})
plt.yticks([-1.5e-4, 0, 1.5e-4], ['-2', '0', '2'],font={'family':'Arial', 'size':30})
plt.rcParams['font.family']='Times New Roman, SimSun '# 设置字体族，中文为SimSun，英文为Times New Roman
plt.rcParams['mathtext.fontset'] = 'stix'
plt.xlabel('Mode number', fontsize = 32)
plt.ylabel(r'($\beta-\beta_0)$', fontsize = 32)

# g = 1e-5
# Out:
# Text(0, 0.5, '($\\beta-\\beta_0)$')

# %% [markdown]
# ## Logic less

# %%
ytplist=[]
xlist = []
ylist = []
yzlist = [1.440585,1.440583,1.440579,1.440577,1.440251,1.440246,1.440231,1.440226,1.440219,1.440214,1.440203,1.440199,1.440143,1.440142,1.440125,1.440121,1.440120,1.440119,1.440082,1.440078,1.439995,1.439993,1.439966,1.439962,1.439927,1.439926]
for i in range(len(yzlist)):
    xlist.append(i)

xtplist=[14, 15, 16, 17]
y0 = (yzlist[16] + yzlist[15])/2

for i in xtplist:
    ytplist.append(yzlist[i])

for i in range(len(yzlist)):
    yzlist[i] -= y0
for i in range(len(xtplist)): 
    ytplist[i] -= y0
    
plt.plot(xlist, yzlist,'.', markersize = 10, color = 'black')
plt.plot(xtplist, ytplist, 'r.', markersize = 10)

plt.ylim(-2.07e-4, 2e-4)
plt.xlim(0, 30)
plt.xticks([0, 10, 20, 30],font={'family':'Arial', 'size':30})
plt.yticks([-1.5e-4, 0, 1.5e-4], ['-2', '0', '2'],font={'family':'Arial', 'size':30})
plt.rcParams['font.family']='Times New Roman, SimSun '# 设置字体族，中文为SimSun，英文为Times New Roman
plt.rcParams['mathtext.fontset'] = 'stix'
plt.xlabel('Mode number', fontsize = 32)
plt.ylabel(r'($\beta-\beta_0)$', fontsize = 32)

# g = 1e-5
# Out:
# Text(0, 0.5, '($\\beta-\\beta_0)$')

# %% [markdown]
# ## No2 More

# %%
ytplist=[]
xlist = []
ylist = []
yzlist = [1.440586,1.440583,1.440256,1.440256,1.440248,1.440247,1.440247,1.440247,1.440240,1.440239,1.440239,1.440233,1.440232,1.440229,1.440226,1.440224,1.440213,1.440211,1.440209,1.440207,1.440191,1.440189,1.440188,1.440186,1.440172,1.440171,1.440167,1.440167,1.440147,1.440114,1.440094,1.440085,1.440046,1.440042,1.440039,1.440037,1.440016,1.440015,1.440010,1.440009,1.439978,1.439977,1.439971,1.439967,1.439938,1.439938,1.439926,1.439922,1.439916,1.439916,1.439907,1.439906,1.439906,1.439906,1.439892,1.439890,1.439881,1.439880,1.439875,1.439874,1.439871,1.439867,1.439848,1.439846,1.439845,1.439844,1.439843,1.439838,1.439827,1.439823]
for i in range(len(yzlist)):
    xlist.append(i)

xtplist=[28, 29, 30, 31]
y0 = (yzlist[29] + yzlist[30])/2

for i in xtplist:
    ytplist.append(yzlist[i])

for i in range(len(yzlist)):
    yzlist[i] -= y0
for i in range(len(xtplist)): 
    ytplist[i] -= y0
    
plt.plot(xlist, yzlist,'.', markersize = 10, color = 'black')
plt.plot(xtplist, ytplist, 'r.', markersize = 10)

plt.ylim(-2.07e-4, 2.1e-4)
plt.xlim(0, 60)
plt.xticks([0, 10, 20, 30, 40, 50, 60],font={'family':'Arial', 'size':30})
plt.yticks([-1.5e-4, 0, 1.5e-4], ['-2', '0', '2'],font={'family':'Arial', 'size':30})
plt.rcParams['font.family']='Times New Roman, SimSun '# 设置字体族，中文为SimSun，英文为Times New Roman
plt.rcParams['mathtext.fontset'] = 'stix'
plt.xlabel('Mode number', fontsize = 32)
plt.ylabel(r'($\beta-\beta_0)$', fontsize = 32)

# g = 1e-5
# Out:
# Text(0, 0.5, '($\\beta-\\beta_0)$')

# %% [markdown]
# ## NO2 less

# %%
ytplist=[]
xlist = []
ylist = []
yzlist = [1.440586,1.440583,1.440241,1.440234,1.440221,1.440214,1.440212,1.440207,1.440147,1.440114,1.440095,1.440085,1.440008,1.439994,1.439984,1.439974,1.439915,1.439907]
for i in range(len(yzlist)):
    xlist.append(i)

xtplist=[8, 9, 10, 11]
y0 = (yzlist[9] + yzlist[10])/2

for i in xtplist:
    ytplist.append(yzlist[i])

for i in range(len(yzlist)):
    yzlist[i] -= y0
for i in range(len(xtplist)): 
    ytplist[i] -= y0
    
plt.plot(xlist, yzlist,'.', markersize = 10, color = 'black')
plt.plot(xtplist, ytplist, 'r.', markersize = 10)

plt.ylim(-2.3e-4, 2e-4)
plt.xlim(0,20)
plt.xticks([0, 5, 10, 15, 20],font={'family':'Arial', 'size':30})
plt.yticks([-1.5e-4, 0, 1.5e-4], ['-2', '0', '2'],font={'family':'Arial', 'size':30})
plt.rcParams['font.family']='Times New Roman, SimSun '# 设置字体族，中文为SimSun，英文为Times New Roman
plt.rcParams['mathtext.fontset'] = 'stix'
plt.xlabel('Mode number', fontsize = 32)
plt.ylabel(r'($\beta-\beta_0)$', fontsize = 32)

# g = 1e-5
# Out:
# Text(0, 0.5, '($\\beta-\\beta_0)$')

# %% [markdown]
# ## No.4 more

# %%
ytplist=[]
xlist = []
ylist = []
yzlist = [1.440578,1.440578,1.440254,1.440254,1.440251,1.440250,1.440248,1.440247,1.440245,1.440244,1.440239,1.440236,1.440235,1.440233,1.440225,1.440222,1.440221,1.440218,1.440208,1.440205,1.440203,1.440200,1.440189,1.440186,1.440184,1.440182,1.440171,1.440168,1.440168,1.440166,1.440138,1.440125,1.440116,1.440114,1.440046,1.440044,1.440041,1.440039,1.440023,1.440018,1.440018,1.440012,1.439992,1.439986,1.439984,1.439978,1.439960,1.439954,1.439949,1.439942,1.439942,1.439941,1.439937,1.439936,1.439935,1.439932]
for i in range(len(yzlist)):
    xlist.append(i)

xtplist=[31, 32, 33, 30]
y0 = (yzlist[32] + yzlist[33])/2

for i in xtplist:
    ytplist.append(yzlist[i])

for i in range(len(yzlist)):
    yzlist[i] -= y0
for i in range(len(xtplist)): 
    ytplist[i] -= y0
    
plt.plot(xlist, yzlist,'.', markersize = 10, color = 'black')
plt.plot(xtplist, ytplist, 'r.', markersize = 10)

plt.ylim(-2.1e-4, 2e-4)
plt.xlim(0, 60)
plt.xticks([0, 10, 20, 30, 40, 50, 60],font={'family':'Arial', 'size':30})
plt.yticks([-1.5e-4, 0, 1.5e-4], ['-2', '0', '2'],font={'family':'Arial', 'size':30})
plt.rcParams['font.family']='Times New Roman, SimSun '# 设置字体族，中文为SimSun，英文为Times New Roman
plt.rcParams['mathtext.fontset'] = 'stix'
plt.xlabel('Mode number', fontsize = 32)
plt.ylabel(r'($\beta-\beta_0)$', fontsize = 32)

# g = 1e-5
# Out:
# Text(0, 0.5, '($\\beta-\\beta_0)$')

# %% [markdown]
# ## No.4 Less

# %%
ytplist=[]
xlist = []
ylist = []
yzlist = [1.440579,1.440576,1.440233,1.440225,1.440215,1.440207,1.440147,1.440122,1.440116,1.440114,1.439985,1.439977,1.439948,1.439944]
for i in range(len(yzlist)):
    xlist.append(i)

xtplist=[6, 7, 8, 9]
y0 = (yzlist[7] + yzlist[8])/2

for i in xtplist:
    ytplist.append(yzlist[i])

for i in range(len(yzlist)):
    yzlist[i] -= y0
for i in range(len(xtplist)): 
    ytplist[i] -= y0
    
plt.plot(xlist, yzlist,'.', markersize = 10, color = 'black')
plt.plot(xtplist, ytplist, 'r.', markersize = 10)

plt.ylim(-2.3e-4, 2e-4)
plt.xlim(0,15)
plt.xticks([0, 5, 10, 15],font={'family':'Arial', 'size':30})
plt.yticks([-1.5e-4, 0, 1.5e-4], ['-2', '0', '2'],font={'family':'Arial', 'size':30})
plt.rcParams['font.family']='Times New Roman, SimSun '# 设置字体族，中文为SimSun，英文为Times New Roman
plt.rcParams['mathtext.fontset'] = 'stix'
plt.xlabel('Mode number', fontsize = 32)
plt.ylabel(r'($\beta-\beta_0)$', fontsize = 32)

# g = 1e-5
# Out:
# Text(0, 0.5, '($\\beta-\\beta_0)$')

# %% [markdown]
# ## 2阶

# %% [markdown]
# No.2

# %%
y_0list = []
y_1list = []
y_2list = []
y_3list = []
xlist = []
ylist = []
yzlist = [1.440789,1.440789,1.440789,1.440789,1.440788,1.440788,1.440788,1.440788,1.440786,1.440786,1.440786,1.440786,1.440784,1.440784,1.440784,1.440784,1.440782,1.440782,1.440742,1.440742,1.440738,1.440737,1.440701,1.440700,1.440700,1.440700,1.440699,1.440698,1.440698,1.440698,1.440697,1.440696,1.440695,1.440695,1.440694,1.440694,1.440693,1.440693,1.440692,1.440692]
for i in range(len(yzlist)):
    xlist.append(i)
x_0list = [0, 1]
x_1list = [2, 3, 4, 5]
x_2list = [6, 7, 8, 9]
x_3list = [18, 19, 20, 21]
y0 = (yzlist[19] + yzlist[20])/2

for i in x_0list:
    y_0list.append(yzlist[i])


for i in x_1list:
    y_1list.append(yzlist[i])

for i in x_2list:
    y_2list.append(yzlist[i])

for i in x_3list:
    y_3list.append(yzlist[i])    
for i in range(len(yzlist)):
    yzlist[i] -= y0
for i in range(len(x_3list)): 
    y_3list[i] -= y0
    
plt.plot(xlist, yzlist,'.', markersize = 10, color = 'black')
#plt.plot(x_1list, y_1list, 'r.', markersize = 10)
#plt.plot(x_2list, y_2list, 'g.', markersize = 10)
plt.plot(x_3list, y_3list, 'r.', markersize = 10)

#plt.ylim(-2.3e-4, 2e-4)
#plt.xlim(0,15)
#plt.xticks([0, 5, 10, 15],font={'family':'Arial', 'size':30})
#plt.yticks([-1.5e-4, 0, 1.5e-4], ['-2', '0', '2'],font={'family':'Arial', 'size':30})
plt.rcParams['font.family']='Times New Roman, SimSun '# 设置字体族，中文为SimSun，英文为Times New Roman
plt.rcParams['mathtext.fontset'] = 'stix'
plt.xlabel('Mode number', fontsize = 32)
plt.ylabel(r'($\beta-\beta_0)$', fontsize = 32)

# g = 1e-5
# Out:
# Text(0, 0.5, '($\\beta-\\beta_0)$')

# %% [markdown]
# No.4

# %%
y_0list = []
y_1list = []
y_2list = []
y_3list = []
xlist = []
ylist = []
yzlist = [1.440789,1.440789,1.440789,1.440789,1.440788,1.440788,1.440788,1.440788,1.440787,1.440787,1.440787,1.440787,1.440785,1.440785,1.440785,1.440785,1.440784,1.440784,1.440784,1.440784,1.440743,1.440742,1.440742,1.440742,1.440701,1.440701,1.440700,1.440700,1.440699,1.440699,1.440699,1.440699,1.440697,1.440697,1.440696,1.440696,1.440694,1.440694,1.440694,1.440694,1.440693,1.440693,1.440692,1.440692]
for i in range(len(yzlist)):
    xlist.append(i)
x_0list = [0, 1]
x_1list = [2, 3, 4, 5]
x_2list = [6, 7, 8, 9]
x_3list = [20, 21, 22, 23]
#y0 = (yzlist[7] + yzlist[8])/2

for i in x_0list:
    y_0list.append(yzlist[i])


for i in x_1list:
    y_1list.append(yzlist[i])

for i in x_2list:
    y_2list.append(yzlist[i])

for i in x_3list:
    y_3list.append(yzlist[i])    
#for i in range(len(yzlist)):
    #yzlist[i] -= y0
#for i in range(len(xtplist)): 
    #ytplist[i] -= y0
    
plt.plot(xlist, yzlist,'.', markersize = 10, color = 'black')
#plt.plot(x_1list, y_1list, 'r.', markersize = 10)
#plt.plot(x_2list, y_2list, 'g.', markersize = 10)
plt.plot(x_3list, y_3list, 'r.', markersize = 10)

#plt.ylim(-2.3e-4, 2e-4)
#plt.xlim(0,15)
#plt.xticks([0, 5, 10, 15],font={'family':'Arial', 'size':30})
#plt.yticks([-1.5e-4, 0, 1.5e-4], ['-2', '0', '2'],font={'family':'Arial', 'size':30})
plt.rcParams['font.family']='Times New Roman, SimSun '# 设置字体族，中文为SimSun，英文为Times New Roman
plt.rcParams['mathtext.fontset'] = 'stix'
plt.xlabel('Mode number', fontsize = 32)
plt.ylabel(r'($\beta-\beta_0)$', fontsize = 32)

# g = 1e-5
# Out:
# Text(0, 0.5, '($\\beta-\\beta_0)$')

# %% [markdown]
# ## 三阶

# %% [markdown]
# No.2

# %%
y_0list = []
y_1list = []
y_2list = []
y_3list = []
xlist = []
ylist = []
yzlist = [1.440417,1.440417,1.440417,1.440417,1.440412,1.440412,1.440412,1.440412,1.440406,1.440406,1.440406,1.440405,1.440400,1.440399,1.440399,1.440399,1.440377,1.440377,1.440334,1.440332,1.440312,1.440312,1.440267,1.440266,1.440244,1.440244,1.440244,1.440244,1.440232,1.440232,1.440231,1.440231,1.440217,1.440216,1.440216,1.440216,1.440204,1.440204,1.440204,1.440204]
for i in range(len(yzlist)):
    xlist.append(i)
x_0list = [0, 1]
x_1list = [2, 3, 4, 5]
x_2list = [6, 7, 8, 9]
x_3list = [18, 19, 20, 21]
y0 = (yzlist[19] + yzlist[20])/2

for i in x_0list:
    y_0list.append(yzlist[i])


for i in x_1list:
    y_1list.append(yzlist[i])

for i in x_2list:
    y_2list.append(yzlist[i])

for i in x_3list:
    y_3list.append(yzlist[i])    
for i in range(len(yzlist)):
    yzlist[i] -= y0
for i in range(len(x_3list)): 
    y_3list[i] -= y0
    
plt.plot(xlist, yzlist,'.', markersize = 10, color = 'black')
#plt.plot(x_1list, y_1list, 'r.', markersize = 10)
#plt.plot(x_2list, y_2list, 'g.', markersize = 10)
plt.plot(x_3list, y_3list, 'r.', markersize = 10)

#plt.ylim(-2.3e-4, 2e-4)
#plt.xlim(0,15)
#plt.xticks([0, 5, 10, 15],font={'family':'Arial', 'size':30})
#plt.yticks([-1.5e-4, 0, 1.5e-4], ['-2', '0', '2'],font={'family':'Arial', 'size':30})
plt.rcParams['font.family']='Times New Roman, SimSun '# 设置字体族，中文为SimSun，英文为Times New Roman
plt.rcParams['mathtext.fontset'] = 'stix'
plt.xlabel('Mode number', fontsize = 32)
plt.ylabel(r'($\beta-\beta_0)$', fontsize = 32)

# g = 1e-5
# Out:
# Text(0, 0.5, '($\\beta-\\beta_0)$')

# %% [markdown]
# No.4

# %%
y_0list = []
y_1list = []
y_2list = []
y_3list = []
xlist = []
ylist = []
yzlist = [1.440418,1.440418,1.440417,1.440417,1.440414,1.440414,1.440414,1.440414,1.440409,1.440409,1.440409,1.440409,1.440403,1.440403,1.440403,1.440403,1.440399,1.440399,1.440398,1.440398,1.440334,1.440333,1.440332,1.440331,1.440246,1.440246,1.440246,1.440246,1.440237,1.440237,1.440237,1.440237,1.440225,1.440225,1.440225,1.440225,1.440213,1.440213,1.440212,1.440212]
for i in range(len(yzlist)):
    xlist.append(i)
x_0list = [0, 1]
x_1list = [2, 3, 4, 5]
x_2list = [6, 7, 8, 9]
x_3list = [20, 21, 22, 23]
y0 = (yzlist[21] + yzlist[22])/2

for i in x_0list:
    y_0list.append(yzlist[i])


for i in x_1list:
    y_1list.append(yzlist[i])

for i in x_2list:
    y_2list.append(yzlist[i])

for i in x_3list:
    y_3list.append(yzlist[i])    
for i in range(len(yzlist)):
    yzlist[i] -= y0
for i in range(len(x_3list)): 
    y_3list[i] -= y0
    
plt.plot(xlist, yzlist,'.', markersize = 10, color = 'black')
#plt.plot(x_1list, y_1list, 'r.', markersize = 10)
#plt.plot(x_2list, y_2list, 'g.', markersize = 10)
plt.plot(x_3list, y_3list, 'r.', markersize = 10)

#plt.ylim(-2.3e-4, 2e-4)
#plt.xlim(0,15)
#plt.xticks([0, 5, 10, 15],font={'family':'Arial', 'size':30})
#plt.yticks([-1.5e-4, 0, 1.5e-4], ['-2', '0', '2'],font={'family':'Arial', 'size':30})
plt.rcParams['font.family']='Times New Roman, SimSun '# 设置字体族，中文为SimSun，英文为Times New Roman
plt.rcParams['mathtext.fontset'] = 'stix'
plt.xlabel('Mode number', fontsize = 32)
plt.ylabel(r'($\beta-\beta_0)$', fontsize = 32)

# g = 1e-5
# Out:
# Text(0, 0.5, '($\\beta-\\beta_0)$')

# %% [markdown]
# ## 四阶

# %% [markdown]
# No.2

# %%
y_0list = []
y_1list = []
y_2list = []
y_3list = []
xlist = []
ylist = []
yzlist = [1.441425,1.441425,1.441385,1.441385,1.441384,1.441384,1.441267,1.441267,1.441266,1.441266,1.441077,1.441077,1.441076,1.441075,1.440858,1.440858,1.440858,1.440858,1.440857,1.440857,1.440857,1.440857,1.440855,1.440855,1.440855,1.440855,1.440854,1.440854,1.440854,1.440854,1.440840,1.440840,1.440818,1.440818,1.440816,1.440816,1.440795,1.440794,1.440781,1.440781,1.440781,1.440781,1.440779,1.440779,1.440779,1.440779,1.440777,1.440777,1.440777,1.440777]
for i in range(len(yzlist)):
    xlist.append(i)
x_0list = [0, 1]
x_1list = [2, 3, 4, 5]
x_2list = [6, 7, 8, 9]
x_3list = [32, 33, 34, 35]
y0 = (yzlist[33] + yzlist[34])/2

for i in x_0list:
    y_0list.append(yzlist[i])


for i in x_1list:
    y_1list.append(yzlist[i])

for i in x_2list:
    y_2list.append(yzlist[i])

for i in x_3list:
    y_3list.append(yzlist[i])    
for i in range(len(yzlist)):
    yzlist[i] -= y0
for i in range(len(x_3list)): 
    y_3list[i] -= y0
    
plt.plot(xlist, yzlist,'.', markersize = 10, color = 'black')
#plt.plot(x_1list, y_1list, 'r.', markersize = 10)
#plt.plot(x_2list, y_2list, 'g.', markersize = 10)
plt.plot(x_3list, y_3list, 'r.', markersize = 10)

#plt.ylim(-2.3e-4, 2e-4)
#plt.xlim(0,15)
#plt.xticks([0, 5, 10, 15],font={'family':'Arial', 'size':30})
#plt.yticks([-1.5e-4, 0, 1.5e-4], ['-2', '0', '2'],font={'family':'Arial', 'size':30})
plt.rcParams['font.family']='Times New Roman, SimSun '# 设置字体族，中文为SimSun，英文为Times New Roman
plt.rcParams['mathtext.fontset'] = 'stix'
plt.xlabel('Mode number', fontsize = 32)
plt.ylabel(r'($\beta-\beta_0)$', fontsize = 32)

# g = 1e-5
# Out:
# Text(0, 0.5, '($\\beta-\\beta_0)$')

# %%
y_0list = []
y_1list = []
y_2list = []
y_3list = []
xlist = []
ylist = []
yzlist = [1.440858,1.440858,1.440858,1.440858,1.440857,1.440857,1.440857,1.440857,1.440855,1.440855,1.440855,1.440855,1.440854,1.440854,1.440854,1.440854,1.440840,1.440840,1.440818,1.440818,1.440816,1.440816,1.440795,1.440794,1.440781,1.440781,1.440781,1.440781,1.440779,1.440779,1.440779,1.440779,1.440777,1.440777,1.440777,1.440777]
for i in range(len(yzlist)):
    xlist.append(i)
x_0list = [0, 1]
x_1list = [2, 3, 4, 5]
x_2list = [6, 7, 8, 9]
x_3list = [18, 19, 20, 21]
y0 = (yzlist[19] + yzlist[20])/2

for i in x_0list:
    y_0list.append(yzlist[i])


for i in x_1list:
    y_1list.append(yzlist[i])

for i in x_2list:
    y_2list.append(yzlist[i])

for i in x_3list:
    y_3list.append(yzlist[i])    
for i in range(len(yzlist)):
    yzlist[i] -= y0
for i in range(len(x_3list)): 
    y_3list[i] -= y0
    
plt.plot(xlist, yzlist,'.', markersize = 10, color = 'black')
#plt.plot(x_1list, y_1list, 'r.', markersize = 10)
#plt.plot(x_2list, y_2list, 'g.', markersize = 10)
plt.plot(x_3list, y_3list, 'r.', markersize = 10)

#plt.ylim(-2.3e-4, 2e-4)
#plt.xlim(0,15)
#plt.xticks([0, 5, 10, 15],font={'family':'Arial', 'size':30})
#plt.yticks([-1.5e-4, 0, 1.5e-4], ['-2', '0', '2'],font={'family':'Arial', 'size':30})
plt.rcParams['font.family']='Times New Roman, SimSun '# 设置字体族，中文为SimSun，英文为Times New Roman
plt.rcParams['mathtext.fontset'] = 'stix'
plt.xlabel('Mode number', fontsize = 32)
plt.ylabel(r'($\beta-\beta_0)$', fontsize = 32)

# g = 1e-5
# Out:
# Text(0, 0.5, '($\\beta-\\beta_0)$')

# %% [markdown]
# No.4

# %%
y_0list = []
y_1list = []
y_2list = []
y_3list = []
xlist = []
ylist = []
yzlist = [1.440858,1.440858,1.440858,1.440858,1.440857,1.440857,1.440857,1.440857,1.440856,1.440856,1.440856,1.440856,1.440855,1.440855,1.440855,1.440855,1.440854,1.440854,1.440854,1.440854,1.440818,1.440818,1.440818,1.440818,1.440781,1.440781,1.440781,1.440781,1.440780,1.440780,1.440780,1.440780,1.440778,1.440778,1.440778,1.440778,1.440776,1.440776,1.440776,1.440776,1.440775,1.440775,1.440775,1.440775]
for i in range(len(yzlist)):
    xlist.append(i)
x_0list = [0, 1]
x_1list = [2, 3, 4, 5]
x_2list = [6, 7, 8, 9]
x_3list = [20, 21, 22, 23]
y0 = (yzlist[21] + yzlist[22])/2

for i in x_0list:
    y_0list.append(yzlist[i])


for i in x_1list:
    y_1list.append(yzlist[i])

for i in x_2list:
    y_2list.append(yzlist[i])

for i in x_3list:
    y_3list.append(yzlist[i])    
for i in range(len(yzlist)):
    yzlist[i] -= y0
for i in range(len(x_3list)): 
    y_3list[i] -= y0
    
plt.plot(xlist, yzlist,'.', markersize = 10, color = 'black')
#plt.plot(x_1list, y_1list, 'r.', markersize = 10)
#plt.plot(x_2list, y_2list, 'g.', markersize = 10)
plt.plot(x_3list, y_3list, 'r.', markersize = 10)

#plt.ylim(-2.3e-4, 2e-4)
#plt.xlim(0,15)
#plt.xticks([0, 5, 10, 15],font={'family':'Arial', 'size':30})
#plt.yticks([-1.5e-4, 0, 1.5e-4], ['-2', '0', '2'],font={'family':'Arial', 'size':30})
plt.rcParams['font.family']='Times New Roman, SimSun '# 设置字体族，中文为SimSun，英文为Times New Roman
plt.rcParams['mathtext.fontset'] = 'stix'
plt.xlabel('Mode number', fontsize = 32)
plt.ylabel(r'($\beta-\beta_0)$', fontsize = 32)

# g = 1e-5
# Out:
# Text(0, 0.5, '($\\beta-\\beta_0)$')

# %% [markdown]
# ## EXTRAS

# %% [markdown]
# No.4

# %%
ytplist=[]
xlist = []
ylist = []
yzlist = [1.440255,1.440254,1.440246,1.440246,1.440245,1.440242,1.440237,1.440233,1.440228,1.440222,1.440220,1.440215,1.440205,1.440198,1.440198,1.440191,1.440179,1.440174,1.440172,1.440168,1.440147,1.440118,1.440114,1.440113,1.440042,1.440037,1.440033,1.440030,1.440004,1.439999,1.439993,1.439989,1.439953,1.439950,1.439941,1.439939,1.439915,1.439914]
for i in range(len(yzlist)):
    xlist.append(i)

xtplist=[20, 21, 22, 23]
y0 = (yzlist[21] + yzlist[22])/2

for i in xtplist:
    ytplist.append(yzlist[i])

for i in range(len(yzlist)):
    yzlist[i] -= y0
for i in range(len(xtplist)): 
    ytplist[i] -= y0
    
plt.plot(xlist, yzlist,'.', markersize = 10, color = 'black')
plt.plot(xtplist, ytplist, 'r.', markersize = 10)

#plt.ylim(-2.3e-4, 2e-4)
#plt.xlim(0, 60)
plt.xticks([0, 10, 20, 30, 40],font={'family':'Arial', 'size':30})
plt.yticks([-1.5e-4, 0, 1.5e-4], ['-2', '0', '2'],font={'family':'Arial', 'size':30})
plt.rcParams['font.family']='Times New Roman, SimSun '# 设置字体族，中文为SimSun，英文为Times New Roman
plt.rcParams['mathtext.fontset'] = 'stix'
plt.xlabel('Mode number', fontsize = 32)
plt.ylabel(r'($\beta-\beta_0)$', fontsize = 32)

# g = 1e-5
# Out:
# Text(0, 0.5, '($\\beta-\\beta_0)$')

# %%
ytplist=[]
xlist = []
ylist = []
yzlist = [1.440255,1.440255,1.440246,1.440245,1.440245,1.440242,1.440236,1.440233,1.440228,1.440223,1.440220,1.440214,1.440205,1.440198,1.440197,1.440190,1.440179,1.440174,1.440172,1.440168,1.440134,1.440118,1.440112,1.440099,1.440043,1.440039,1.440032,1.440028,1.440007,1.439997,1.439996,1.439988,1.439957,1.439949,1.439945,1.439938,1.439915,1.439915,1.439904,1.439902,1.439901,1.439898,1.439894]
for i in range(len(yzlist)):
    xlist.append(i)

xtplist=[20, 21, 22, 23]
y0 = (yzlist[21] + yzlist[22])/2

for i in xtplist:
    ytplist.append(yzlist[i])
print(ytplist)
for i in range(len(yzlist)):
    yzlist[i] -= y0
for i in range(len(xtplist)): 
    ytplist[i] -= y0
    
plt.plot(xlist, yzlist,'.', markersize = 10, color = 'black')
plt.plot(xtplist, ytplist, 'r.', markersize = 10)

#plt.ylim(-2.3e-4, 2e-4)
#plt.xlim(0, 60)
plt.xticks([0, 10, 20, 30, 40],font={'family':'Arial', 'size':30})
plt.yticks([-1.5e-4, 0, 1.5e-4], ['-2', '0', '2'],font={'family':'Arial', 'size':30})
plt.rcParams['font.family']='Times New Roman, SimSun '# 设置字体族，中文为SimSun，英文为Times New Roman
plt.rcParams['mathtext.fontset'] = 'stix'
plt.xlabel('Mode number', fontsize = 32)
plt.ylabel(r'($\beta-\beta_0)$', fontsize = 32)

# g = 1e-5
# Out:
# [1.440134, 1.440118, 1.440112, 1.440099]
# Text(0, 0.5, '($\\beta-\\beta_0)$')

# %%
ytplist=[]
xlist = []
ylist = []
yzlist = [1.440253,1.440252,1.440249,1.440248,1.440243,1.440240,1.440239,1.440236,1.440226,1.440223,1.440220,1.440217,1.440203,1.440200,1.440196,1.440193,1.440177,1.440174,1.440172,1.440170,1.440122,1.440116,1.440114,1.440107,1.440041,1.440037,1.440036,1.440032,1.440006,1.440000,1.439997,1.439991,1.439963,1.439954,1.439953,1.439942,1.439940,1.439940,1.439933,1.439930,1.439929,1.439927,1.439924]
for i in range(len(yzlist)):
    xlist.append(i)

xtplist=[20, 21, 22, 23]
y0 = (yzlist[21] + yzlist[22])/2

for i in xtplist:
    ytplist.append(yzlist[i])
print(ytplist)
for i in range(len(yzlist)):
    yzlist[i] -= y0
for i in range(len(xtplist)): 
    ytplist[i] -= y0
    
plt.plot(xlist, yzlist,'.', markersize = 10, color = 'black')
plt.plot(xtplist, ytplist, 'r.', markersize = 10)

#plt.ylim(-2.3e-4, 2e-4)
#plt.xlim(0, 60)
plt.xticks([0, 10, 20, 30, 40],font={'family':'Arial', 'size':30})
plt.yticks([-1.5e-4, 0, 1.5e-4], ['-2', '0', '2'],font={'family':'Arial', 'size':30})
plt.rcParams['font.family']='Times New Roman, SimSun '# 设置字体族，中文为SimSun，英文为Times New Roman
plt.rcParams['mathtext.fontset'] = 'stix'
plt.xlabel('Mode number', fontsize = 32)
plt.ylabel(r'($\beta-\beta_0)$', fontsize = 32)

# g = 1e-5
# Out:
# [1.440122, 1.440116, 1.440114, 1.440107]
# Text(0, 0.5, '($\\beta-\\beta_0)$')

# %% [markdown]
# NO.2

# %%
ytplist=[]
xlist = []
ylist = []
yzlist = [1.440250,1.440249,1.440248,1.440248,1.440238,1.440237,1.440233,1.440231,1.440228,1.440227,1.440207,1.440205,1.440204,1.440203,1.440177,1.440176,1.440176,1.440175,1.440108,1.440102,1.440086,1.440083,1.440038,1.440036,1.440034,1.440031,1.439999,1.439995,1.439990,1.439985,1.439959,1.439955,1.439955,1.439953,1.439949,1.439944,1.439944,1.439943,1.439937,1.439935,1.439926,1.439926,1.439925,]
for i in range(len(yzlist)):
    xlist.append(i)

xtplist=[18, 19, 20, 21]
y0 = (yzlist[19] + yzlist[20])/2

for i in xtplist:
    ytplist.append(yzlist[i])
print(ytplist)
for i in range(len(yzlist)):
    yzlist[i] -= y0
for i in range(len(xtplist)): 
    ytplist[i] -= y0
    
plt.plot(xlist, yzlist,'.', markersize = 10, color = 'black')
plt.plot(xtplist, ytplist, 'r.', markersize = 10)

#plt.ylim(-2.3e-4, 2e-4)
#plt.xlim(0, 60)
plt.xticks([0, 10, 20, 30, 40],font={'family':'Arial', 'size':30})
plt.yticks([-1.5e-4, 0, 1.5e-4], ['-2', '0', '2'],font={'family':'Arial', 'size':30})
plt.rcParams['font.family']='Times New Roman, SimSun '# 设置字体族，中文为SimSun，英文为Times New Roman
plt.rcParams['mathtext.fontset'] = 'stix'
plt.xlabel('Mode number', fontsize = 32)
plt.ylabel(r'($\beta-\beta_0)$', fontsize = 32)

# g = 1e-5
# Out:
# [1.440108, 1.440102, 1.440086, 1.440083]
# Text(0, 0.5, '($\\beta-\\beta_0)$')

# %% [markdown]
# No.4 12 24

# %%
y1tplist = []
y2tplist = []
xlist = []
ylist = []
yzlist = [1.440182,1.440182,1.440180,1.440180,1.440176,1.440176,1.440172,1.440172,1.440169,1.440169,1.440169,1.440169,1.440167,1.440167,1.440165,1.440164,1.440161,1.440161,1.440158,1.440158,1.440147,1.440135,1.440128,1.440114,1.440099,1.440099,1.440092,1.440091,1.440086,1.440086,1.440084,1.440083,1.440082,1.440082,1.440076,1.440076,1.440075,1.440075]
for i in range(len(yzlist)):
    xlist.append(i)
x1tplist=[20, 23]
x2tplist=[21, 22]
y0 = (yzlist[21] + yzlist[22])/2

for i in x2tplist:
    y2tplist.append(yzlist[i])
    
for i in x1tplist:
    y1tplist.append(yzlist[i])
print(ytplist)
for i in range(len(yzlist)):
    yzlist[i] -= y0
for i in range(len(x2tplist)): 
    y2tplist[i] -= y0
for i in range(len(x1tplist)): 
    y1tplist[i] -= y0

    
plt.plot(xlist, yzlist,'.', markersize = 10, color = 'black')
plt.plot(x2tplist, y2tplist, 'r.', markersize = 10)
plt.plot(x1tplist, y1tplist, 'b.', markersize = 10)

#plt.ylim(-2.3e-4, 2e-4)
#plt.xlim(0, 60)
#plt.xticks([0, 10, 20, 30, 40],font={'family':'Arial', 'size':30})
#plt.yticks([-1.5e-4, 0, 1.5e-4], ['-2', '0', '2'],font={'family':'Arial', 'size':30})
plt.rcParams['font.family']='Times New Roman, SimSun '# 设置字体族，中文为SimSun，英文为Times New Roman
plt.rcParams['mathtext.fontset'] = 'stix'
plt.xlabel('Mode number', fontsize = 32)
plt.ylabel(r'($\beta-\beta_0)$', fontsize = 32)

# g = 1e-5
# Out:
# [-1.4401220000000003, -1.4401280000000003, -1.4401350000000002, -1.4401560000000002]
# Text(0, 0.5, '($\\beta-\\beta_0)$')

# %%
y1tplist = []
y2tplist = []
xlist = []
ylist = []
yzlist = [1.440182,1.440182,1.440180,1.440180,1.440176,1.440176,1.440172,1.440172,1.440169,1.440169,1.440169,1.440169,1.440167,1.440167,1.440165,1.440164,1.440161,1.440161,1.440158,1.440158,1.440135,1.440134,1.440128,1.440099,1.440099,1.440099,1.440092,1.440091,1.440086,1.440086,1.440084,1.440083,1.440082,1.440082,1.440076,1.440076,1.440075,1.440075]
for i in range(len(yzlist)):
    xlist.append(i)
x1tplist=[21, 24]
x2tplist=[20, 22]
y0 = (yzlist[20] + yzlist[22])/2

for i in x2tplist:
    y2tplist.append(yzlist[i])
    
for i in x1tplist:
    y1tplist.append(yzlist[i])
print(ytplist)
for i in range(len(yzlist)):
    yzlist[i] -= y0
for i in range(len(x2tplist)): 
    y2tplist[i] -= y0
for i in range(len(x1tplist)): 
    y1tplist[i] -= y0

    
plt.plot(xlist, yzlist,'.', markersize = 10, color = 'black')
plt.plot(x2tplist, y2tplist, 'r.', markersize = 10)
plt.plot(x1tplist, y1tplist, 'b.', markersize = 10)

#plt.ylim(-2.3e-4, 2e-4)
#plt.xlim(0, 60)
#plt.xticks([0, 10, 20, 30, 40],font={'family':'Arial', 'size':30})
#plt.yticks([-1.5e-4, 0, 1.5e-4], ['-2', '0', '2'],font={'family':'Arial', 'size':30})
plt.rcParams['font.family']='Times New Roman, SimSun '# 设置字体族，中文为SimSun，英文为Times New Roman
plt.rcParams['mathtext.fontset'] = 'stix'
plt.xlabel('Mode number', fontsize = 32)
plt.ylabel(r'($\beta-\beta_0)$', fontsize = 32)

# g = 1e-5
# Out:
# [-1.4401220000000003, -1.4401280000000003, -1.4401350000000002, -1.4401560000000002]
# Text(0, 0.5, '($\\beta-\\beta_0)$')
